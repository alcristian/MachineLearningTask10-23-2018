# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import graphviz
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()


#Geracao do mapa
from folium import plugins 
import folium

#ajuste de datas
import calendar

# ANOVA
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm_api
from statsmodels.formula.api import ols as sm_ols

# %matplotlib inline

# %%
#importing datasets
#df_2001_2004 = pd.read_csv('Chicago_Crimes_2001_to_2004.csv',error_bad_lines=False)
df_crimes1 = pd.read_csv('Chicago_Crimes_2001_to_2004.csv',error_bad_lines=False)
df_crimes2 = pd.read_csv('Chicago_Crimes_2005_to_2007.csv',error_bad_lines=False)
df_crimes3 = pd.read_csv('Chicago_Crimes_2008_to_2011.csv',error_bad_lines=False)
df_crimes4 = pd.read_csv('Chicago_Crimes_2012_to_2017.csv',error_bad_lines=False)

df_crimedata = pd.concat([df_crimes1, df_crimes2, df_crimes3,df_crimes4], ignore_index=False, axis=0)

del df_crimes1
del df_crimes2
del df_crimes3
del df_crimes4
# Out:
# b'Skipping line 1513591: expected 23 fields, saw 24\n'
# C:\Users\chaos\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2705: DtypeWarning: Columns (17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# b'Skipping line 533719: expected 23 fields, saw 24\n'
# b'Skipping line 1149094: expected 23 fields, saw 41\n'

# %%
df_crimedata.head()
# Out:
#    Unnamed: 0       ID Case Number                    Date  \
# 0         879  4786321    HM399414  01/01/2004 12:01:00 AM
# 1        2544  4676906    HM278933  03/01/2003 12:00:00 AM
# 2        2919  4789749    HM402220  06/20/2004 11:00:00 AM
# 3        2927  4789765    HM402058  12/30/2004 08:00:00 PM
# 4        3302  4677901    HM275615  05/01/2003 01:00:00 AM
#
#                  Block  IUCR                Primary Type  \
# 0    082XX S COLES AVE  0840                       THEFT
# 1      004XX W 42ND PL  2825               OTHER OFFENSE
# 2  025XX N KIMBALL AVE  1752  OFFENSE INVOLVING CHILDREN
# 3   045XX W MONTANA ST  0840                       THEFT
# 4   111XX S NORMAL AVE  0841                       THEFT
#
#                       Description Location Description  Arrest  \
# 0   FINANCIAL ID THEFT: OVER $300            RESIDENCE   False
# 1         HARASSMENT BY TELEPHONE            RESIDENCE   False
# 2   AGG CRIM SEX ABUSE FAM MEMBER            RESIDENCE   False
# ...

# %%
#procurando dados nulos
null_data = df_crimedata[df_crimedata.isnull().any(axis=1)]
null_data.head(5)
# Out:
#    Unnamed: 0       ID Case Number                    Date  \
# 0         879  4786321    HM399414  01/01/2004 12:01:00 AM
# 2        2919  4789749    HM402220  06/20/2004 11:00:00 AM
# 3        2927  4789765    HM402058  12/30/2004 08:00:00 PM
# 5        3633  4838048    HM440266  08/01/2004 12:01:00 AM
# 8        4564  4792195    HM405396  09/16/2004 10:00:00 AM
#
#                  Block  IUCR                Primary Type  \
# 0    082XX S COLES AVE  0840                       THEFT
# 2  025XX N KIMBALL AVE  1752  OFFENSE INVOLVING CHILDREN
# 3   045XX W MONTANA ST  0840                       THEFT
# 5  012XX S HARDING AVE  0841                       THEFT
# 8   003XX W HUBBARD ST  0890                       THEFT
#
#                       Description Location Description  Arrest   ...     Ward  \
# 0   FINANCIAL ID THEFT: OVER $300            RESIDENCE   False   ...      7.0
# 2   AGG CRIM SEX ABUSE FAM MEMBER            RESIDENCE   False   ...     35.0
# ...

# %%
df_crimedata.shape
# Out:
# (7941282, 23)

# %%
df_crimedata.describe()
# Out:
#          Unnamed: 0            ID          Beat      District          Ward  \
# count  7.941282e+06  7.941282e+06  7.941282e+06  7.941191e+06  7.241058e+06
# mean   2.673858e+06  5.926071e+06  1.197659e+03  1.131215e+01  2.262089e+01
# std    1.816327e+06  2.568290e+06  7.041944e+02  6.944523e+00  1.378632e+01
# min    0.000000e+00  6.340000e+02  1.110000e+02  1.000000e+00  1.000000e+00
# 25%    1.160283e+06  3.853209e+06  6.230000e+02  6.000000e+00  1.000000e+01
# 50%    2.282372e+06  6.165079e+06  1.111000e+03  1.000000e+01  2.200000e+01
# 75%    4.185491e+06  7.716590e+06  1.732000e+03  1.700000e+01  3.400000e+01
# max    6.254267e+06  1.082788e+07  2.535000e+03  3.100000e+01  5.000000e+01
#
#        Community Area  X Coordinate          Year     Longitude
# count    7.239191e+06  7.835709e+06  7.941282e+06  7.835708e+06
# mean     3.774790e+01  1.164455e+06  2.007672e+03 -8.767203e+01
# std      2.156597e+01  1.751911e+04  4.123451e+00  6.328715e-02
# ...

# %%
#deletando casos duplicados
df_crimedata.drop_duplicates(subset=['ID', 'Case Number'], inplace=True)

# %%
#percentual de dados faltantes
missing_data_per = df_crimedata.isna().sum()*100/len(df_crimedata)
missing_data_per
#existem dados faltantes nas colunas Case Number, Location Description, District, Ward, Community Area, X Coordinate, y Coordinate, Latitude, Longitude, Location
# Out:
# Unnamed: 0              0.000000
# ID                      0.000000
# Case Number             0.000065
# Date                    0.000000
# Block                   0.000000
# IUCR                    0.000000
# Primary Type            0.000000
# Description             0.000000
# Location Description    0.031892
# Arrest                  0.000000
# Domestic                0.000000
# Beat                    0.000000
# District                0.000794
# Ward                    9.964070
# Community Area          9.983143
# FBI Code                0.000000
# X Coordinate            1.364861
# Y Coordinate            1.364861
# Year                    0.000000
# Updated On              0.000000
# Latitude                1.364861
# Longitude               1.364861
# Location                1.364861
# dtype: float64

# %%
#Remocao das das colunas com a maior porcentagem de dados faltantes. 

df_crimedata = df_crimedata.drop(columns=['Unnamed: 0', 'Case Number', 'Block', 'IUCR', 'Location Description',
                                    'Domestic', 'Updated On', 'FBI Code', 'X Coordinate', 'Y Coordinate', 
                                    'Latitude', 'Longitude', 'Location'], axis = 1)

df_crimedata.head()
# Out:
#         ID                    Date                Primary Type  \
# 0  4786321  01/01/2004 12:01:00 AM                       THEFT
# 1  4676906  03/01/2003 12:00:00 AM               OTHER OFFENSE
# 2  4789749  06/20/2004 11:00:00 AM  OFFENSE INVOLVING CHILDREN
# 3  4789765  12/30/2004 08:00:00 PM                       THEFT
# 4  4677901  05/01/2003 01:00:00 AM                       THEFT
#
#                       Description  Arrest  Beat  District  Ward  \
# 0   FINANCIAL ID THEFT: OVER $300   False   424       4.0   7.0
# 1         HARASSMENT BY TELEPHONE   False   935       9.0  11.0
# 2   AGG CRIM SEX ABUSE FAM MEMBER   False  1413      14.0  35.0
# 3   FINANCIAL ID THEFT: OVER $300   False  2521      25.0  31.0
# 4  FINANCIAL ID THEFT:$300 &UNDER   False  2233      22.0  34.0
#
#    Community Area    Year
# 0            46.0  2004.0
# 1            61.0  2003.0
# 2            22.0  2004.0
# 3            20.0  2004.0
# 4            49.0  2003.0

# %%
#conferir os dados faltantes agora que as colunas com maior porcentagem foram removidas.
missing_data_per = df_crimedata.isna().sum() * 100 / len(df_crimedata)
missing_data_per
# Out:
# ID                0.000000
# Date              0.000000
# Primary Type      0.000000
# Description       0.000000
# Arrest            0.000000
# Beat              0.000000
# District          0.000794
# Ward              9.964070
# Community Area    9.983143
# Year              0.000000
# dtype: float64

# %%
#deletar as linhas que contem null 

df_crimedata = df_crimedata.dropna()
df_crimedata.isnull().sum()
# Out:
# ID                0
# Date              0
# Primary Type      0
# Description       0
# Arrest            0
# Beat              0
# District          0
# Ward              0
# Community Area    0
# Year              0
# dtype: int64

# %%
df_crimedata.shape
# Out:
# (5554662, 10)

# %%
sns.countplot(x='Year',data=df_crimedata, color=('RED'))
fig = plt.gcf()
plt.ylabel('Num de Crimes')
fig.set_size_inches(15,5)

plt.show()
#numero total de crimes de Chicago vem diminuindo durante os anos.

# %%
#convertendo os dados Float em Strings
df_crimedata[['District', 'Ward','Community Area']] = df_crimedata[['District', 'Ward','Community Area']].astype('int')
df_crimedata[['District', 'Ward','Community Area']] = df_crimedata[['District', 'Ward','Community Area']].astype('str')
df_crimedata.head()
# Out:
#         ID                    Date                Primary Type  \
# 0  4786321  01/01/2004 12:01:00 AM                       THEFT
# 1  4676906  03/01/2003 12:00:00 AM               OTHER OFFENSE
# 2  4789749  06/20/2004 11:00:00 AM  OFFENSE INVOLVING CHILDREN
# 3  4789765  12/30/2004 08:00:00 PM                       THEFT
# 4  4677901  05/01/2003 01:00:00 AM                       THEFT
#
#                       Description  Arrest  Beat District Ward Community Area  \
# 0   FINANCIAL ID THEFT: OVER $300   False   424        4    7             46
# 1         HARASSMENT BY TELEPHONE   False   935        9   11             61
# 2   AGG CRIM SEX ABUSE FAM MEMBER   False  1413       14   35             22
# 3   FINANCIAL ID THEFT: OVER $300   False  2521       25   31             20
# 4  FINANCIAL ID THEFT:$300 &UNDER   False  2233       22   34             49
#
#      Year
# 0  2004.0
# 1  2003.0
# 2  2004.0
# 3  2004.0
# 4  2003.0

# %%
#separando os dados por ano, a partir de 2005 

df_crimedata2005 = df_crimedata[df_crimedata["Year"]==2005]
df_crimedata2006 = df_crimedata[df_crimedata["Year"]==2006]
df_crimedata2007 = df_crimedata[df_crimedata["Year"]==2007]
df_crimedata2008 = df_crimedata[df_crimedata["Year"]==2008]
df_crimedata2009 = df_crimedata[df_crimedata["Year"]==2009]
df_crimedata2010 = df_crimedata[df_crimedata["Year"]==2010]
df_crimedata2011 = df_crimedata[df_crimedata["Year"]==2011]
df_crimedata2012 = df_crimedata[df_crimedata["Year"]==2012]
df_crimedata2013 = df_crimedata[df_crimedata["Year"]==2013]
df_crimedata2014 = df_crimedata[df_crimedata["Year"]==2014]
df_crimedata2015 = df_crimedata[df_crimedata["Year"]==2015]
df_crimedata2016 = df_crimedata[df_crimedata["Year"]==2016]
df_crimedata2017 = df_crimedata[df_crimedata["Year"]==2017]

df_crimedatacartheft2016 = df_crimedata2016[df_crimedata2016["Primary Type"]=='MOTOR VEHICLE THEFT']
#todos os roubos de carro disponiveis
df_crimedatacartheft = df_crimedata[df_crimedata["Primary Type"]=='MOTOR VEHICLE THEFT']

# %%
#Mapa Crimes Chicago by Ward
#vou utilizar os dados de 2016 porque Chicago implementou o sistema de Boundries em 2015 entao pode haver incoerencias. 

#https://www.cityofchicago.org/city/en/depts/doit/dataset/boundaries_-_wards.html

geo_crimemap = 'Boundaries - Wards (2015-).geojson'
#calcular o numero de incidentes por distrito em 2016
df_WardCrimes2016 = pd.DataFrame(df_crimedata2016['Ward'].value_counts().astype(float))


df_WardCrimes2016 = df_WardCrimes2016.reset_index()
df_WardCrimes2016.columns = ['ward', 'Qtd_Crimes']
df_WardCrimes2016.to_json('Ward_Map.json')

Chicago_COORDINATES = (41.895140898, -87.624255632)

chicago_map1 = folium.Map(location=Chicago_COORDINATES, zoom_start=11)
chicago_map1.choropleth(geo_data = geo_crimemap, 
                data = df_WardCrimes2016,
                columns = ['ward', 'Qtd_Crimes'],
                key_on = 'feature.properties.ward',
                fill_color = 'YlOrRd', 
                fill_opacity = 0.7, 
                line_opacity = 0.2,
                threshold_scale=[0, 1000, 5000, 10000, 15000],
                legend_name = 'Numero de Incidentes por ~police ward~ em 2016')

chicago_map1.save('map_chicago_by_Ward.html')

# %%
df_WardCrimes2016
# Out:
#    ward  Qtd_Crimes
# 0    42     14614.0
# 1    28     12333.0
# 2    24     11970.0
# 3     2     11242.0
# 4    27     10098.0
# 5    17      8566.0
# 6     6      8545.0
# 7    21      8134.0
# 8    20      7649.0
# 9     8      7065.0
# 10    3      6923.0
# 11    9      6777.0
# 12    7      6774.0
# 13   16      6707.0
# 14   34      6631.0
# 15   37      6603.0
# 16   29      6180.0
# 17   15      6096.0
# 18    5      5917.0
# 19    1      5216.0
# 20    4      4961.0
# 21   32      4698.0
# 22   18      4698.0
# 23   10      4495.0
# 24   44      4364.0
# 25   26      4025.0
# 26   25      3725.0
# 27   43      3598.0
# 28   13      3579.0
# 29   14      3537.0
# 30   30      3479.0
# 31   31      3479.0
# 32   11      3447.0
# 33   49      3426.0
# 34   12      3393.0
# 35   46      3364.0
# 36   35      3352.0
# 37   23      3330.0
# 38   41      3196.0
# 39   22      3115.0
# 40   36      2959.0
# 41   38      2791.0
# 42   45      2748.0
# 43   40      2672.0
# ...

# %%
#Mapa de roubo de carros Chicago by Ward /MOTOR VEHICLE THEFT/
#vou utilizar os dados de 2016 porque Chicago implementou o sistema de Boundries em 2015 entao pode haver incoerencias. 

#https://www.cityofchicago.org/city/en/depts/doit/dataset/boundaries_-_wards.html

geo_crimemap2 = 'Boundaries - Wards (2015-).geojson'
#calcular o numero de incidentes por distrito em 2016
df_WardCarTheft2016 = pd.DataFrame(df_crimedatacartheft2016['Ward'].value_counts().astype(float))

df_WardCarTheft2016 = df_WardCarTheft2016.reset_index()
df_WardCarTheft2016.columns = ['ward', 'Qtd_Crimes']
df_WardCarTheft2016.to_json('Ward_Map.json')

Chicago_COORDINATES = (41.895140898, -87.624255632)

chicago_map2 = folium.Map(location=Chicago_COORDINATES, zoom_start=11)
chicago_map2.choropleth(geo_data = geo_crimemap2, 
                data = df_WardCarTheft2016,
                columns = ['ward', 'Qtd_Crimes'],
                key_on = 'feature.properties.ward',
                fill_color = 'YlOrRd', 
                fill_opacity = 0.7, 
                line_opacity = 0.2,
                threshold_scale=[0, 100, 200, 400, 600],
                legend_name = 'Numero de Roubos de carro por ~police ward~ em 2016')

chicago_map2.save('map_car_theft_by_Ward.html')

# %%
#df_WardCarTheft2016 = df_crimedata2016.loc[df_crimedata2016['Primary Type'] == 'MOTOR VEHICLE THEFT']
df_WardCarTheft2016
# Out:
#    ward  Qtd_Crimes
# 0    24       503.0
# 1    28       496.0
# 2     2       379.0
# 3    27       376.0
# 4    37       366.0
# 5     6       360.0
# 6    18       341.0
# 7     8       321.0
# 8    29       319.0
# 9    21       302.0
# 10   34       292.0
# 11    3       281.0
# 12   16       274.0
# 13   17       274.0
# 14    1       268.0
# 15   20       268.0
# 16   31       266.0
# 17   26       258.0
# 18   42       253.0
# 19   30       250.0
# 20    7       249.0
# 21   15       242.0
# 22    9       241.0
# 23    5       229.0
# 24   14       227.0
# 25   32       210.0
# 26    4       207.0
# 27   13       206.0
# 28   35       200.0
# 29   38       189.0
# 30   23       184.0
# 31   25       173.0
# 32   22       165.0
# 33   12       163.0
# 34   33       163.0
# 35   11       157.0
# 36   10       155.0
# 37   44       151.0
# 38   39       151.0
# 39   41       150.0
# 40   50       143.0
# 41   43       126.0
# 42   36       122.0
# 43   45       117.0
# ...

# %%
#Distribuicao dos dados 
sns.set()
columns = df_crimedatacartheft2016.columns.tolist()
sns.pairplot(df_crimedatacartheft2016[columns],height = 2 ,kind ='scatter',diag_kind='kde')
plt.show()
# Out:
# C:\Users\chaos\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\chaos\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
#Ajustando as datas
df_crimedata['Date'] = pd.to_datetime(df_crimedata['Date'],format='%m/%d/%Y %I:%M:%S %p')
df_crimedata['Month']=(df_crimedata['Date'].dt.month).apply(lambda x: calendar.month_abbr[x])
df_crimedata['Month'] = pd.Categorical(df_crimedata['Month'] , categories=['Jan','Feb','Mar','Apr','May',
                                                'Jun','Jul','Aug','Sep','Oct','Nov','Dec'], ordered=True)
months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# %%
df_crimedata.groupby(['Month','Year'])['ID'].count().unstack().plot(marker='o', figsize=(15,10))
plt.xticks(np.arange(12),months)
plt.ylabel('Numero de Crimes')

plt.show()

# %%
#Ajustando as datas e Plot de roubo de carros
df_crimedatacartheft['Date'] = pd.to_datetime(df_crimedatacartheft['Date'],format='%m/%d/%Y %I:%M:%S %p')
df_crimedatacartheft['Month']=(df_crimedatacartheft['Date'].dt.month).apply(lambda x: calendar.month_abbr[x])
df_crimedatacartheft['Month'] = pd.Categorical(df_crimedatacartheft['Month'] , categories=['Jan','Feb','Mar','Apr','May',
                                                'Jun','Jul','Aug','Sep','Oct','Nov','Dec'], ordered=True)
months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']


df_crimedatacartheft.groupby(['Month','Year'])['ID'].count().unstack().plot(marker='o', figsize=(15,10))
plt.xticks(np.arange(12),months)
plt.ylabel('Numero de roubos de carro')


plt.show()
# Out:
# C:\Users\chaos\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chaos\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\chaos\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#Verificar o grafico de 2016 
df_crimedatacartheft2016['Date'] = pd.to_datetime(df_crimedatacartheft2016['Date'],format='%m/%d/%Y %I:%M:%S %p')
df_crimedatacartheft2016['Month']=(df_crimedatacartheft2016['Date'].dt.month).apply(lambda x: calendar.month_abbr[x])
df_crimedatacartheft2016['Month'] = pd.Categorical(df_crimedatacartheft2016['Month'] , categories=['Jan','Feb','Mar','Apr','May',
                                                'Jun','Jul','Aug','Sep','Oct','Nov','Dec'], ordered=True)
months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']


df_crimedatacartheft2016.groupby(['Month','Year'])['ID'].count().unstack().plot(marker='o', figsize=(15,10))
plt.xticks(np.arange(12),months)
plt.ylabel('Numero de roubos de carro 2016')


plt.show()
# Out:
# C:\Users\chaos\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chaos\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\chaos\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#agrupando total de crimes 
dfy = df_crimedatacartheft2016.groupby(['Date']).size()
dfy = dfy.reset_index()
dfy.columns = ['Date', 'Qtd_Crimes']
dfy = dfy.groupby(dfy['Date'].dt.date).size()
dfy = dfy.reset_index()
dfy.columns = ['Date', 'Qtd_Crimes']
dfy['Date'] = pd.to_datetime(dfy['Date'])

dfy['Qtd_Crimes'] = dfy['Qtd_Crimes'].astype(float)
dfy = dfy.reset_index()
dfy.head()
# Out:
#    index       Date  Qtd_Crimes
# 0      0 2016-01-01        22.0
# 1      1 2016-01-02        22.0
# 2      2 2016-01-03        24.0
# 3      3 2016-01-04        25.0
# 4      4 2016-01-05        19.0

# %%
dfy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 3 columns):
# index         366 non-null int64
# Date          366 non-null datetime64[ns]
# Qtd_Crimes    366 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 8.7 KB

# %%
#aplicando FbProphet para predizer os dados utilizando somente 2016 como base.
from fbprophet import Prophet
dfy = dfy.rename(columns={'Date': 'ds', 'Qtd_Crimes': 'y'})
CarTheft_model = Prophet(interval_width=0.95)
CarTheft_model.fit(dfy)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\chaos\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
CarTheft_forecast = CarTheft_model.make_future_dataframe(periods=36, freq='MS')
CarTheft_forecast = CarTheft_model.predict(furniture_forecast)

# %%
plt.figure(figsize=(18, 6))
CarTheft_model.plot(CarTheft_forecast, xlabel = 'Date', ylabel = 'Roubos')
plt.title('Roubo de carros Predicao');

# %%
#Refazendo os agrupamentos para toda a base de dados.

dfall = df_crimedatacartheft.groupby(['Date']).size()
dfall = dfall.reset_index()
dfall.columns = ['Date', 'Qtd_Crimes']

dfall = dfall.groupby(dfall['Date'].dt.date).size()
dfall = dfall.reset_index()
dfall.columns = ['Date', 'Qtd_Crimes']
dfall['Date'] = pd.to_datetime(dfall['Date'])

dfall['Qtd_Crimes'] = dfall['Qtd_Crimes'].astype(float)
dfall = dfall.reset_index()
dfall.head()
# Out:
#    index       Date  Qtd_Crimes
# 0      0 2001-01-01         3.0
# 1      1 2001-01-02         1.0
# 2      2 2001-01-03         1.0
# 3      3 2001-01-05         2.0
# 4      4 2001-01-06         2.0

# %%
#aplicando FbProphet para predizer os dados utilizando toda a base.

dfall = dfall.rename(columns={'Date': 'ds', 'Qtd_Crimes': 'y'})
CarTheftAll_model = Prophet(interval_width=0.95)
CarTheftAll_model.fit(dfall)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\chaos\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
CarTheftAll_forecast = CarTheftAll_model.make_future_dataframe(periods=36, freq='MS')
CarTheftAll_forecast = CarTheftAll_model.predict(CarTheftAll_forecast)

# %%
plt.figure(figsize=(18, 6))
CarTheftAll_model.plot(CarTheftAll_forecast, xlabel = 'Data', ylabel = 'Quantidade de Roubos')
plt.title('Roubo de carros Predicao');

# %%
CarTheftAll_model.plot_components(CarTheftAll_forecast);

# %%
#cross validation
from fbprophet.diagnostics import cross_validation

df_cv = cross_validation(CarTheftAll_model, initial='730 days', period='180 days', horizon = '365 days')
df_cv.head()
# Out:
# INFO:fbprophet.diagnostics:Making 27 forecasts with cutoffs between 2003-03-28 00:00:00 and 2016-01-19 00:00:00
# C:\Users\chaos\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
#           ds       yhat  yhat_lower  yhat_upper     y     cutoff
# 0 2003-03-29  44.424322   36.335292   51.762450  28.0 2003-03-28
# 1 2003-03-30  43.738784   35.118807   51.650861  45.0 2003-03-28
# 2 2003-03-31  43.837418   36.043882   51.995333  44.0 2003-03-28
# 3 2003-04-01  44.404359   36.081629   51.863984  40.0 2003-03-28
# 4 2003-04-02  44.441013   37.094632   52.352725  31.0 2003-03-28

# %%
from fbprophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#      horizon        mse      rmse       mae      mape  coverage
# 5474 37 days  73.781964  8.589643  5.947879  0.689807  0.920489
# 2189 37 days  73.520229  8.574394  5.934811  0.689320  0.921509
# 4379 37 days  73.519894  8.574374  5.934619  0.689305  0.921509
# 6569 37 days  73.373561  8.565837  5.923038  0.689070  0.921509
# 4744 37 days  73.328831  8.563226  5.916590  0.688798  0.921509

# %%
from fbprophet.plot import plot_cross_validation_metric
df_cv
fig = plot_cross_validation_metric(df_cv, metric='mape')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-ea5231ea06ba> in <module>()
#       1 from fbprophet.plot import plot_cross_validation_metric
#       2 df_cv
# ----> 3 fig = plot_cross_validation_metric(df_cv, metric='mape')
#
# C:\Users\chaos\Anaconda3\lib\site-packages\fbprophet\plot.py in plot_cross_validation_metric(df_cv, metric, rolling_window, ax)
#     462             break
#     463
# --> 464     x_plt = df_none['horizon'].astype('timedelta64[ns]').astype(int) / float(dt_conversions[i])
#     465     x_plt_h = df_h['horizon'].astype('timedelta64[ns]').astype(int) / float(dt_conversions[i])
#     466
#
# C:\Users\chaos\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
# ...

# %%
#quebra por dia
# By Day
sales_by_day = df.groupby('Day').size()
plot_by_day = sales_by_day.plot(title='Daily Sales',xticks=(range(1,31)),rot=55)
plot_by_day.set_xlabel('Day')
plot_by_day.set_ylabel('Total Sales')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-255e94cad164> in <module>()
#       1 #quebra por dia
#       2 # By Day
# ----> 3 sales_by_day = df.groupby('Day').size()
#       4 plot_by_day = sales_by_day.plot(title='Daily Sales',xticks=(range(1,31)),rot=55)
#       5 plot_by_day.set_xlabel('Day')
#
# NameError: name 'df' is not defined

# %%
df_2001_2004_theft_x = df_2001_2004.loc[df_2001_2004['Primary Type'] == 'MOTOR VEHICLE THEFT', ['Date','Primary Type','Description','Location Description','Arrest', 'Ward', 'Community Area', 'Beat']]
df_2001_2004_theft_x['Date'] = pd.to_datetime(df_2001_2004_theft_x['Date'])

# %%
df_2001_2004_theft_x.head()
# Out:
#                    Date         Primary Type                 Description  \
# 22  2003-10-31 14:00:00  MOTOR VEHICLE THEFT                  AUTOMOBILE
# 91  2004-08-17 09:27:00  MOTOR VEHICLE THEFT             ATT: AUTOMOBILE
# 119 2004-02-18 18:28:00  MOTOR VEHICLE THEFT  THEFT/RECOVERY: AUTOMOBILE
# 120 2004-09-02 09:32:00  MOTOR VEHICLE THEFT                  AUTOMOBILE
# 121 2004-11-13 03:56:28  MOTOR VEHICLE THEFT                  AUTOMOBILE
#
#     Location Description  Arrest  Ward  Community Area  Beat
# 22           GAS STATION   False  15.0            67.0   725
# 91                 ALLEY   False  17.0            68.0   733
# 119               STREET   False  16.0            67.0   725
# 120               STREET   False  20.0            68.0   711
# 121               STREET   False  17.0            67.0   734

# %%
df_2001_2004_theft_x.shape
# Out:
# (98924, 8)

# %%
df_2001_2004_theft_x.groupby('Arrest').size()
# Out:
# Arrest
# False    86918
# True     12006
# dtype: int64

# %%
df_2001_2004_theft_x.describe()
# Out:
#                Ward  Community Area          Beat
# count  61460.000000     61458.00000  98924.000000
# mean      21.763781        38.53635   1239.482482
# std       13.329859        21.21265    703.388153
# min        1.000000         0.00000    111.000000
# 25%       10.000000        23.00000    711.000000
# 50%       21.000000        34.00000   1112.000000
# 75%       32.000000        59.00000   1731.000000
# max       50.000000        77.00000   2535.000000

# %%
sns.pairplot(df_2001_2004_theft_x.dropna())
